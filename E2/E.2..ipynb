# %% [markdown]
# ### ELIAS CORREA 05/10/2021
# Crear una carpeta nueva en su repositorio git con el nombre E2.
#
# Dentro de E2 crear una carpeta que se llame data.
#
# Guardar los datos asignados en esa carpeta.
#
# Dentro de E2 debera crear un Jupyter Notebook llamado E2.
#
# En el Jupyter Notebook, configurar la primera casilla en Lenguaje Markdown y escribir su nombre, fecha, y esta lista de instrucciones de forma ordenada.
#
# Importar la libreria csv y matplotlib.pyplot de python para poder procesar y graficar los datos del archivo. Debe separar el código en las casillas que estime conveniente, pero se solicita minimo que en una casilla esten solo las importaciones, en otra solo la lectura de los datos y otra con los plots, además cada casilla debe tener una casilla previa que describa el código en formato markdown.
#
# Hacer los gráficos correspondientes al conjunto de datos seleccionado.
#
# Utilizar los comandos adecuados de git para actualizar su repositorio y dejarlo disponible en github de forma pública.

# %% [markdown]
# #### En este ejercicio se debera importar numpy, scipy, pandas y matplotlib.pyplot

# %%
import numpy as np
import scipy as stats
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Con pd.read_csv se llamaran los datos 'CasosGeneroEtario.csv' y lo guardaremos en la variable casos

# %%
casos = pd.read_csv('CasosGeneroEtario.csv')
casos
# Out:
#     Grupo de edad Sexo  2020-03-25  2020-03-26  2020-03-27  2020-03-28  \
# 0    00 - 04 años    M           4           5           5           5
# 1    05 - 09 años    M           2           2           2           4
# 2    10 - 14 años    M           7           8           8          10
# 3    15 - 19 años    M           8           9          13          16
# 4    20 - 24 años    M          25          32          35          46
# 5    25 - 29 años    M          61          75          87         100
# 6    30 - 34 años    M          88         106         115         137
# 7    35 - 39 años    M          72          86          96         119
# 8    40 - 44 años    M          62          71          82          97
# 9    45 - 49 años    M          47          55          69          86
# 10   50 - 54 años    M          28          45          53          72
# 11   55 - 59 años    M          30          34          44          58
# ...

# %% [markdown]
# ##### El metodo dtypes no ayudara a ver que tipo de dato es cada columna (object,int,float..etc)

# %%
casos.dtypes
# Out:
# Grupo de edad    object
# Sexo             object
# 2020-03-25        int64
# 2020-03-26        int64
# 2020-03-27        int64
#                   ...
# 2021-09-13        int64
# 2021-09-17        int64
# 2021-09-20        int64
# 2021-09-24        int64
# 2021-09-27        int64
# Length: 185, dtype: object

# %% [markdown]
# ##### El método describe devuelve información estadística de los datos del dataframe

# %%
casos.describe()
# Out:
#        2020-03-25  2020-03-26  2020-03-27  2020-03-28  2020-03-29  2020-03-30  \
# count   34.000000   34.000000   34.000000   34.000000   34.000000   34.000000
# mean    29.764706   36.823529   42.176471   50.676471   56.058824   61.411765
# std     26.906188   32.494727   36.427155   42.285982   45.757557   49.627777
# min      2.000000    2.000000    2.000000    4.000000    4.000000    4.000000
# 25%      7.000000    8.250000    9.500000   13.000000   14.250000   15.750000
# 50%     21.500000   29.000000   33.000000   42.500000   51.000000   54.500000
# 75%     47.750000   58.750000   69.000000   84.250000   94.250000  107.250000
# max     88.000000  106.000000  115.000000  137.000000  144.000000  160.000000
#
#        2020-03-31  2020-04-01  2020-04-02  2020-04-03  ...     2021-08-27  \
# count   34.000000   34.000000   34.000000   34.000000  ...      34.000000
# mean    69.794118   80.705882   86.411765   99.941176  ...   57332.352941
# ...

# %% [markdown]
# ##### Se puede deducir que en cada columna de todas las fechas nos das la promedio, la desviación estandar, los percentiles(25%,50%,75%),y se puede ver que tiene valores distintos, los valores minimos y maximos de cada columna y por ultimo nos muestra con el count cuantas filas tiene las columnas

# %% [markdown]
# ##### El metodo shape nos ayudara a ver cuantas filas y columnas tienes nuestros datos
# ##### En este caso vemos que nuestros datos tienen 34 filas y 185 columnas

# %%
casos.shape
# Out:
# (34, 185)

# %% [markdown]
# #### En este caso, la parte una nos pide graficar los datos acumulados por sexo de casos en el tiempo, con .drop eliminaremos 'Grupo de edad' ya que no nos piden esos datos, además con set_index colocaremos 'Sexo' como indice

# %%
casos.drop(columns='Grupo de edad', inplace=True)
casos.set_index('Sexo', inplace=True)
casos
# Out:
#       2020-03-25  2020-03-26  2020-03-27  2020-03-28  2020-03-29  2020-03-30  \
# Sexo
# M              4           5           5           5           5           5
# M              2           2           2           4           4           4
# M              7           8           8          10          10          10
# M              8           9          13          16          17          18
# M             25          32          35          46          52          58
# M             61          75          87         100         107         116
# M             88         106         115         137         139         149
# M             72          86          96         119         133         142
# M             62          71          82          97         112         125
# M             47          55          69          86          95         108
# M             28          45          53          72          74          83
# ...

# %% [markdown]
# ##### En el ejeX con el np.arange y len nos ayuda a grafica ya que con len que es un tipo de dato que devuelve la cantidad de artículos en un contenedor, asi que devolvera la columa 'Sexo'

# %%
ejeX=np.arange(len(casos.columns),step=1)
xlabels=list (casos.columns)

# %%
casos.T.plot(figsize=(100,10), xlabel="FECHAS POR SEMANA", ylabel=" CANTIDAD DE CASOS" , 
         title = "Gráficos acumulados por sexo de casos en el tiempo", xticks=ejeX, rot=90)
# Out:
# <AxesSubplot:title={'center':'Gráficos acumulados por sexo de casos en el tiempo'}, xlabel='FECHAS POR SEMANA', ylabel=' CANTIDAD DE CASOS'>

# %% [markdown]
# #### Ejercicio 2: Para este ejercicio haremos lo mismo, llamaremos 'CasosGeneroEtario.csv' con pd.read_csv

# %%
casos = pd.read_csv('CasosGeneroEtario.csv', index_col=0)
casos
# Out:
#               Sexo  2020-03-25  2020-03-26  2020-03-27  2020-03-28  \
# Grupo de edad
# 00 - 04 años     M           4           5           5           5
# 05 - 09 años     M           2           2           2           4
# 10 - 14 años     M           7           8           8          10
# 15 - 19 años     M           8           9          13          16
# 20 - 24 años     M          25          32          35          46
# 25 - 29 años     M          61          75          87         100
# 30 - 34 años     M          88         106         115         137
# 35 - 39 años     M          72          86          96         119
# 40 - 44 años     M          62          71          82          97
# 45 - 49 años     M          47          55          69          86
# 50 - 54 años     M          28          45          53          72
# 55 - 59 años     M          30          34          44          58
# 60 - 64 años     M          18          26          31          39
# ...

# %% [markdown]
# #### La diferencia es que en la segunda parte nos pide gráficar por grupo etario sin importar sexo en el tiempo, asi que con ayuda de .drop borraremos la columna 'Sexo'

# %%
casos.drop(columns='Sexo',inplace=True)
casos
# Out:
#                2020-03-25  2020-03-26  2020-03-27  2020-03-28  2020-03-29  \
# Grupo de edad
# 00 - 04 años            4           5           5           5           5
# 05 - 09 años            2           2           2           4           4
# 10 - 14 años            7           8           8          10          10
# 15 - 19 años            8           9          13          16          17
# 20 - 24 años           25          32          35          46          52
# 25 - 29 años           61          75          87         100         107
# 30 - 34 años           88         106         115         137         139
# 35 - 39 años           72          86          96         119         133
# 40 - 44 años           62          71          82          97         112
# 45 - 49 años           47          55          69          86          95
# 50 - 54 años           28          45          53          72          74
# ...

# %% [markdown]
# #### En el ejeX con el np.arange y len nos ayuda a grafica ya que con len que es un tipo de dato que devuelve la cantidad de artículos en un contenedor, asi que devolvera la columa 'Grupo de edad'

# %%
ejeX=np.arange(len(casos.columns),step=1)
xlabels=list (casos.columns)

# %%
casos.T.plot(figsize=(100,10), xlabel="FECHAS POR SEMANA", ylabel=" CANTIDAD DE CASOS" , 
         title = "Gráficos por grupo etario sin importar sexo en el tiempo", xticks=ejeX, rot=90)
# Out:
# <AxesSubplot:title={'center':'Gráficos por grupo etario sin importar sexo en el tiempo'}, xlabel='FECHAS POR SEMANA', ylabel=' CANTIDAD DE CASOS'>
